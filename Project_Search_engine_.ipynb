# %% [markdown]
# # Overview

# %% [markdown]
# **Introduction**

# %% [markdown]
# Reading is a great way to gain knowledge, improve vocabulary, and relax the mind. However, not everyone is passionate about reading, especially beginner adult readers. Therefore, building a book recommendation tool can help them discover books that match their interests, preferences, and reading levels. In this paper, I will explore the problem of building a book recommendation tool for beginner adult readers, the value of the solution, the data source, the techniques used, and the challenges faced.

# %% [markdown]
# The data from Goodreads data , it is a website where you can keep track of what you read and find recommendations.
#
# Goodreads book data was scrapped by reseacher at UCSD and it can be dowloaded via this link https://sites.google.com/eng.ucsd.edu/ucsdbookgraph/home
#
# USCD data is used instead of API because there is no API , Goodreads ended their API acces.

# %% [markdown]
# # **Data** **Explanation**

# %% [markdown]
# 1.   **goodreads_interactions.csv**  : For every user , it has what books they read and how the books
#
# *   **user_id :** A unique ID for each user on Goodreads
# *   **book_id :** Unique ID for each book on Goodreads
# *   **Rating** : each row tells how the user rated a particular book . From 0-5
#
#
# 2.   **Goodreads_books**.**json**.**gz** : it is a json file , million of lines and each line is metadata about a specific book
#
# *   **Tittle** : Title of the book on Goodreads
# *   **book_id** : Unique ID for each book on Goodreads
# *   **ratings_count**: how many times the book has been rated by user
#
# 3.   **book_id_map**.**csv** ": Map the book id from one data set to the other data set to make sure that we are refering to the same book
#
# *   **book_id_csv** : book_id of goodreads_intereactions
# *   **book_id** : book_id of Goodreads_books.json.gz
#
#
# 4.   **Books_titles**.**json**: It will be used for Collective filtering, it is based on personal books preferences.
#
#
#
# *   **book_id** : Unique ID for each book on Goodreads
# *   **title**: Title of the book on Goodreads
# *   **ratings**: each row tells how the user rated a particular book . From 0-5
# *   **url** : url to access the book online
# *   **cover_image**: image of the book cover
# *   **mod_title**:adjusted book search result

# %% [markdown]
# # **Load** **Data**

# %% [markdown]
# **Goodreads_books**.**json**.**gz** contains millions of data and it will be difficult to load all the data without using all the memory. The json file will be loaded line by line.

# %%
import gzip # Instead of reading the whole file into memory at once, let's read it line by line to use less memory

with gzip.open("/content/drive/MyDrive/Data Magic Uploads/Data/goodreads_books.json.gz", 'r') as f:
     line = f.readline() #streamthe file without unzipping it

# %%
line #read a single line in from the file, it contains data about a single book, like the title , number of times it was rated the bookid
# Out:
# b'{"isbn": "0312853122", "text_reviews_count": "1", "series": [], "country_code": "US", "language_code": "", "popular_shelves": [{"count": "3", "name": "to-read"}, {"count": "1", "name": "p"}, {"count": "1", "name": "collection"}, {"count": "1", "name": "w-c-fields"}, {"count": "1", "name": "biography"}], "asin": "", "is_ebook": "false", "average_rating": "4.00", "kindle_asin": "", "similar_books": [], "description": "", "format": "Paperback", "link": "https://www.goodreads.com/book/show/5333265-w-c-fields", "authors": [{"author_id": "604031", "role": ""}], "publisher": "St. Martin\'s Press", "num_pages": "256", "publication_day": "1", "isbn13": "9780312853129", "publication_month": "9", "edition_information": "", "publication_year": "1984", "url": "https://www.goodreads.com/book/show/5333265-w-c-fields", "image_url": "https://images.gr-assets.com/books/1310220028m/5333265.jpg", "book_id": "5333265", "ratings_count": "3", "work_id": "5400751", "title": "W.C. Fields: A Life on Film", "title_without_series": "W.C. Fields: A Life on Film"}\n'

# %% [markdown]
# From the output above, one line contain information about one book which is "title": "W.C. Fields: A Life on Film", and it list the ratings_count, book_id and other informations about the book.

# %% [markdown]
# # **Data** **Cleaning**

# %%
import json # use this json module to load the single line from the file which will turn it into a dictionary where we a can access each property

json.loads(line)
# Out:
# {'isbn': '0312853122',
#  'text_reviews_count': '1',
#  'series': [],
#  'country_code': 'US',
#  'language_code': '',
#  'popular_shelves': [{'count': '3', 'name': 'to-read'},
#   {'count': '1', 'name': 'p'},
#   {'count': '1', 'name': 'collection'},
#   {'count': '1', 'name': 'w-c-fields'},
#   {'count': '1', 'name': 'biography'}],
#  'asin': '',
#  'is_ebook': 'false',
#  'average_rating': '4.00',
#  'kindle_asin': '',
#  'similar_books': [],
#  'description': '',
#  'format': 'Paperback',
#  'link': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'authors': [{'author_id': '604031', 'role': ''}],
#  'publisher': "St. Martin's Press",
#  'num_pages': '256',
#  'publication_day': '1',
#  'isbn13': '9780312853129',
#  'publication_month': '9',
#  'edition_information': '',
#  'publication_year': '1984',
#  'url': 'https://www.goodreads.com/book/show/5333265-w-c-fields',
#  'image_url': 'https://images.gr-assets.com/books/1310220028m/5333265.jpg',
#  'book_id': '5333265',
#  'ratings_count': '3',
#  'work_id': '5400751',
#  'title': 'W.C. Fields: A Life on Film',
#  'title_without_series': 'W.C. Fields: A Life on Film'}

# %%
def parse_fields(line):# will take a single line and return the field needed
    data = json.loads(line)
    return {
        "book_id":data["book_id"],
        "title": data ["title_without_series"],
        "ratings": data["ratings_count"],
        "url": data["url"],
        "cover_image":data["image_url"]
    }

# %%
books_titles = []  #go line by line to parse each line
with gzip.open("/content/drive/MyDrive/Data Magic Uploads/Data/goodreads_books.json.gz", 'r') as f:
     while True:
         line = f.readline()
         if not line: # when it reach the end of the file , it will end
              break
         fields = parse_fields(line)

         try:
              ratings = int(fields["ratings"]) # only want to take books that have more than a certain number of ratings because books that have few ratings make it unlikely for user to read it
         except ValueError:
             continue
         if ratings > 15: # only take books with more than 15 ratings, it will cut down on the data by selecting a small amount of fields
             books_titles.append(fields)

# %%
import pandas as pd

titles = pd.DataFrame.from_dict(books_titles) # turn into a dataframe. books titles will be a list of dictionaries and from_dict will turn those dictionary into a row

# %%
titles["ratings"] = pd.to_numeric(titles["ratings"]) # turn titles ratings into a numerical columns

# %% [markdown]
# ## **Search** **Engine**

# %% [markdown]
# The search engine space should be minimized. To accomplish it the number of potential characters should be minimized meaning if a tittle is capitalized different the search will bring out the same book, like " Books" and "books" is the same thing so the search should come with the same tittle.

# %%
titles["mod_title"] = titles ["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True) # the field will modify the tittle to minimize the search space.

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                                 mod_title
# 0          The Unschooled Wizard Sun Wolf and Starhawk 12
# 1                                    Best Friends Forever
# 2                           The Aeneid for Boys and Girls
# 3        Alls Fairy in Love and War Avalon Web of Magic 8
# 4                                     The Devils Notebook
# ...                                                   ...
# 1308952                          Ondine Ondine Quartet 05
# 1308953     Jacqueline Kennedy Onassis Friend of the Arts
# 1308954                   The Spaniards Blackmailed Bride
# 1308955           The Childrens Classic Poetry Collection
# 1308956               101 Nights Volume One 101 Nights 13
#
# [1308957 rows x 6 columns]

# %% [markdown]
# Looking at the mod_title, the title are stil capitalized and there is a lot of space included in the title.

# %%
titles["mod_title"] = titles ["mod_title"].str.lower() # lower case the titles

# %%
titles["mod_title"] = titles ["mod_title"].str.replace("\s+", " ", regex=True) # remove any spaces in row , if there is 3 spaces in a row will replace with single space

# %% [markdown]
# The goal is to make the search engine a little more efficient

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                                  mod_title
# 0        the unschooled wizard (sun wolf and starhawk, ...
# 1                                     best friends forever
# 2                            the aeneid for boys and girls
# 3        all's fairy in love and war (avalon: web of ma...
# 4                                     the devil's notebook
# ...                                                    ...
# 1308952                      ondine (ondine quartet, #0.5)
# 1308953     jacqueline kennedy onassis: friend of the arts
# 1308954                   the spaniard's blackmailed bride
# 1308955           the children's classic poetry collection
# 1308956          101 nights: volume one (101 nights, #1-3)
#
# [1308957 rows x 6 columns]

# %% [markdown]
# ## **Cleaning** **Missing** **Values**

# %% [markdown]
# To make sure accurate results are displayed missing values will be removed from the search

# %%
titles = titles[titles["mod_title"].str.len() > 0] # remove the all the null tittles by checking the length and only taking the mod titles that are greater than 0

# %%
titles.to_json("books_titles.json") #will be used int future sessions

# %%
titles
# Out:
#           book_id                                              title  ratings  \
# 0         7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1         6066819                               Best Friends Forever    51184
# 2          287141                      The Aeneid for Boys and Girls       46
# 3         6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4          287149                               The Devil's Notebook      986
# ...           ...                                                ...      ...
# 1308952  17805813                      Ondine (Ondine Quartet, #0.5)      327
# 1308953    331839     Jacqueline Kennedy Onassis: Friend of the Arts       18
# 1308954   2685097                   The Spaniard's Blackmailed Bride      112
# 1308955   2342551           The Children's Classic Poetry Collection       36
# 1308956  22017381          101 Nights: Volume One (101 Nights, #1-3)       70
#
#                                                        url  \
# 0        https://www.goodreads.com/book/show/7327624-th...
# 1        https://www.goodreads.com/book/show/6066819-be...
# 2        https://www.goodreads.com/book/show/287141.The...
# 3        https://www.goodreads.com/book/show/6066812-al...
# 4        https://www.goodreads.com/book/show/287149.The...
# ...                                                    ...
# 1308952  https://www.goodreads.com/book/show/17805813-o...
# 1308953  https://www.goodreads.com/book/show/331839.Jac...
# 1308954  https://www.goodreads.com/book/show/2685097-th...
# 1308955  https://www.goodreads.com/book/show/2342551.Th...
# 1308956  https://www.goodreads.com/book/show/22017381-1...
#
#                                                cover_image  \
# 0        https://images.gr-assets.com/books/1304100136m...
# 1        https://s.gr-assets.com/assets/nophoto/book/11...
# 2        https://s.gr-assets.com/assets/nophoto/book/11...
# 3        https://images.gr-assets.com/books/1316637798m...
# 4        https://images.gr-assets.com/books/1328768789m...
# ...                                                    ...
# 1308952  https://images.gr-assets.com/books/1379766592m...
# 1308953  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308954  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308955  https://s.gr-assets.com/assets/nophoto/book/11...
# 1308956  https://images.gr-assets.com/books/1398621236m...
#
#                                                 mod_title
# 0          the unschooled wizard sun wolf and starhawk 12
# 1                                    best friends forever
# 2                           the aeneid for boys and girls
# 3        alls fairy in love and war avalon web of magic 8
# 4                                     the devils notebook
# ...                                                   ...
# 1308952                          ondine ondine quartet 05
# 1308953     jacqueline kennedy onassis friend of the arts
# 1308954                   the spaniards blackmailed bride
# 1308955           the childrens classic poetry collection
# 1308956               101 nights volume one 101 nights 13
#
# [1302659 rows x 6 columns]

# %% [markdown]
# ### **Term** **Frequency** - **Inverse** **Document** **Frequency**

# %% [markdown]
# For the search Engine ,Term Frequency - Inverse Document Frequency (TF-IDF) will be used , it is a widely used statistical method in natural language processing and information retrieval. It measures how important a term is within a document relative to a collection of documents

# %%
from sklearn.feature_extraction.text import TfidfVectorizer # this library builds the TF-IDF matrix
vectorizer = TfidfVectorizer() # this vectorizer will take a lists of the string and turn it into a tfidf matrix

tfidf = vectorizer.fit_transform(titles["mod_title"])

# %% [markdown]
# Turn the search query into a vector match it against the matrix for a comparison

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import re
#to check if you are picking the correct book , clean url with HTML which will give you a list of url you can click on it to check if it is the correct book you want or
# check the image using show image
def make_clickable(val):
    return'<a target="_blank" href="{}">Goodreads</a>'.format(val) # style the column with HTML ,the url will print nicely and have the ability to click on the url

def show_image(val):
    return '<img src="{}" width= 50></img'.format(val)


def search(query, vectorizer):
    processed = re.sub("[^a-zA-Z0-9 ]","",query.lower()) # same processing with the mod titles from earlier and then lowercase the quey
    query_vec = vectorizer.transform([processed]) # turn the query into a vector using the vectorizer
    similarity = cosine_similarity(query_vec, tfidf).flatten() # find the similarity, search the matrix and tell how much each row is similar
    indices = np.argpartition(similarity, -10)[-10:]  # finding the 10th largest similarity values using partition to find indices and values
    results = titles.iloc[indices] # use the indices to index titles
    results = results.sort_values("ratings", ascending=False) # take the rows with the higher numbers of rating to avoid multiples books to be shown
    return results.head(5).style.format({'url':make_clickable, 'cover_image': show_image}) # the url will print nicely and have the ability to click on the url and print the image

# %%
search ("Pachinko", vectorizer)
# Out:
# <style type="text/css">
# </style>
# <table id="T_af578" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af578_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_af578_level0_col1" class="col_heading level0 col1" >title</th>
#       <th id="T_af578_level0_col2" class="col_heading level0 col2" >ratings</th>
#       <th id="T_af578_level0_col3" class="col_heading level0 col3" >url</th>
#       <th id="T_af578_level0_col4" class="col_heading level0 col4" >cover_image</th>
#       <th id="T_af578_level0_col5" class="col_heading level0 col5" >mod_title</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af578_level0_row0" class="row_heading level0 row0" >1062354</th>
#       <td id="T_af578_row0_col0" class="data row0 col0" >29983711</td>
#       <td id="T_af578_row0_col1" class="data row0 col1" >Pachinko</td>
#       <td id="T_af578_row0_col2" class="data row0 col2" >8161</td>
#       <td id="T_af578_row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/29983711-pachinko">Goodreads</a></td>
#       <td id="T_af578_row0_col4" class="data row0 col4" ><img src="https://images.gr-assets.com/books/1462393298m/29983711.jpg" width= 50></img</td>
#       <td id="T_af578_row0_col5" class="data row0 col5" >pachinko</td>
#     </tr>
#     <tr>
#       <th id="T_af578_level0_row1" class="row_heading level0 row1" >436303</th>
#       <td id="T_af578_row1_col0" class="data row1 col0" >32737635</td>
#       <td id="T_af578_row1_col1" class="data row1 col1" >The Most Dangerous Place on Earth</td>
#       <td id="T_af578_row1_col2" class="data row1 col2" >4063</td>
#       <td id="T_af578_row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/32737635-the-most-dangerous-place-on-earth">Goodreads</a></td>
#       <td id="T_af578_row1_col4" class="data row1 col4" ><img src="https://images.gr-assets.com/books/1477347638m/32737635.jpg" width= 50></img</td>
#       <td id="T_af578_row1_col5" class="data row1 col5" >the most dangerous place on earth</td>
#     </tr>
#     <tr>
#       <th id="T_af578_level0_row2" class="row_heading level0 row2" >1086215</th>
#       <td id="T_af578_row2_col0" class="data row2 col0" >32619967</td>
#       <td id="T_af578_row2_col1" class="data row2 col1" >Pachinko</td>
#       <td id="T_af578_row2_col2" class="data row2 col2" >1361</td>
#       <td id="T_af578_row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/32619967-pachinko">Goodreads</a></td>
#       <td id="T_af578_row2_col4" class="data row2 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width= 50></img</td>
#       <td id="T_af578_row2_col5" class="data row2 col5" >pachinko</td>
#     </tr>
#     <tr>
#       <th id="T_af578_level0_row3" class="row_heading level0 row3" >368254</th>
#       <td id="T_af578_row3_col0" class="data row3 col0" >684819</td>
#       <td id="T_af578_row3_col1" class="data row3 col1" >Dreaming Pachinko</td>
#       <td id="T_af578_row3_col2" class="data row3 col2" >283</td>
#       <td id="T_af578_row3_col3" class="data row3 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/684819.Dreaming_Pachinko">Goodreads</a></td>
#       <td id="T_af578_row3_col4" class="data row3 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width= 50></img</td>
#       <td id="T_af578_row3_col5" class="data row3 col5" >dreaming pachinko</td>
#     </tr>
#     <tr>
#       <th id="T_af578_level0_row4" class="row_heading level0 row4" >178483</th>
#       <td id="T_af578_row4_col0" class="data row4 col0" >34051011</td>
#       <td id="T_af578_row4_col1" class="data row4 col1" >Pachinko</td>
#       <td id="T_af578_row4_col2" class="data row4 col2" >254</td>
#       <td id="T_af578_row4_col3" class="data row4 col3" ><a target="_blank" href="https://www.goodreads.com/book/show/34051011-pachinko">Goodreads</a></td>
#       <td id="T_af578_row4_col4" class="data row4 col4" ><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width= 50></img</td>
#       <td id="T_af578_row4_col5" class="data row4 col5" >pachinko</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Make a list of Liked books using the books_id

# %%
liked_books = ["4408", "31147619", "29983711", "9401317", "9317691", "8153988", "20494944"]

# %% [markdown]
# Used the liked book to build some recommendations, Use the goodreader interaction files where it has each user and how much they liked each books to create recommendations for us.
# First find the user that like the same books as us and then find all the books they liked because we'll probably like the same books as them.

# %% [markdown]
# **book_id_map**.**csv** Let's analyze the book_id map.

# %%
# !head "/content/drive/MyDrive/Data Magic Uploads/Data/book_id_map.csv" # returns a specified number of rows, string from the top
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
csv_book_mapping = {}
with open ("/content/drive/MyDrive/Data Magic Uploads/Data/book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split (",") # it reads each line in the file , it's splitting the line on the comma and it is assigning the first part before the comma to cvsid and the second part to book id
        csv_book_mapping[csv_id] = book_id

# %%
len(csv_book_mapping) # check the number of keys/books that can be matched between the data set
# Out:
# 2360651

# %%
# !wc -l "/content/drive/MyDrive/Data Magic Uploads/Data/goodreads_interactions.csv" # to look at the number of lines in the file
# Out:
# 228648343 /content/drive/MyDrive/Data Magic Uploads/Data/goodreads_interactions.csv

# %% [markdown]
# **goodreads_interactions**.**csv** : is the file that has how each user rated each book

# %%
# !head "/content/drive/MyDrive/Data Magic Uploads/Data/goodreads_interactions.csv"
# goodreads_interation.csv is the file that has how each user rated each book
# a row is a rating for one book
# basically we  check the book and we say is this book in our set of liked books, if it is then the user might have similar taste in bookstores
#then check to see the rating , if the rating was highly rated then the user does have similar tasted to us
# add them to a set users with similar tastes in books
# Out:
# user_id,book_id,is_read,rating,is_reviewed
# 0,948,1,5,0
# 0,947,1,5,1
# 0,946,1,5,0
# 0,945,1,5,0
# 0,944,1,5,0
# 0,943,1,5,0
# 0,942,1,5,0
# 0,941,1,5,0
# 0,940,1,5,0

# %% [markdown]
# # **Finding** **the** **Users** **With** **Equal** **Book** **Taste** **than** **US**

# %%
overlap_users = set () # a set python data structure where every element is unique

with open("/content/drive/MyDrive/Data Magic Uploads/Data/goodreads_interactions.csv",'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",") # undersore means the field is not fo interest, this will give user_id, csv_id,and rating

        if user_id in overlap_users: # if the user_id is already added to the set, there is no need to keep proccessing it again
             continue

        try:
             rating = int (rating) # parse the rating as interger
        except ValueError:
            continue
        book_id = csv_book_mapping[csv_id] #turn csv_id into a book_id because the book id is what was used to create a list of liked books

        if book_id in liked_books and rating >=4 :# if the book for the row is the book we like and the rating for the book is >= 4 add the user to overlap users
            overlap_users.add(user_id)

# %% [markdown]
# # **Finding** **What** **Books** **Users** **Liked**

# %%
rec_lines = [] # it will only contain books that users who liked the same books as us have read # will contain all the books we might want to read

with open("/content/drive/MyDrive/Data Magic Uploads/Data/goodreads_interactions.csv",'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.split(",") #split the data # undersore means the field is not fo interest, this will give user_id, csv_id,and rating
        if user_id in overlap_users:
            book_id = csv_book_mapping[csv_id]
            rec_lines.append ([user_id, book_id, rating])

# %%
len(overlap_users) # we can see the number of users who likes the books we liked
# Out:
# 2029

# %%
len(rec_lines) # how many total books the users read and rated a 4 or above
# Out:
# 1530257

# %% [markdown]
# # **Rank** **Users** **Recommendations**

# %%
import pandas as pd

# turn the rec(recommendation) lines into data frame to make it easier to work with
recs = pd.DataFrame(rec_lines, columns=["user_id", "book_id", "rating"])
recs ["book_id"] = recs ["book_id"].astype(str)     # make sure book_id is a string

# %%
#finding the top recommendations
top_recs = recs["book_id"].value_counts().head(10) # tells which book id occurs the most and show you the most common one.
top_recs = top_recs.index.values # get the values of the index

# %% [markdown]
# Once we figure out the top recommendation , now we book_id and value count is left. Get the book_id into a title.

# %%
books_titles = pd.read_json("books_titles.json") # reading our book titles in so we can combine our recommendation with the book titles , to find the recommended tittle
books_titles["book_id"] = books_titles ["book_id"].astype (str) # making sure it is the same data type

# %%
books_titles.head()
# Out:
#    book_id                                              title  ratings  \
# 0  7327624  The Unschooled Wizard (Sun Wolf and Starhawk, ...      140
# 1  6066819                               Best Friends Forever    51184
# 2   287141                      The Aeneid for Boys and Girls       46
# 3  6066812  All's Fairy in Love and War (Avalon: Web of Ma...       98
# 4   287149                               The Devil's Notebook      986
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/7327624-th...
# 1  https://www.goodreads.com/book/show/6066819-be...
# 2  https://www.goodreads.com/book/show/287141.The...
# 3  https://www.goodreads.com/book/show/6066812-al...
# 4  https://www.goodreads.com/book/show/287149.The...
#
#                                          cover_image  \
# 0  https://images.gr-assets.com/books/1304100136m...
# 1  https://s.gr-assets.com/assets/nophoto/book/11...
# 2  https://s.gr-assets.com/assets/nophoto/book/11...
# 3  https://images.gr-assets.com/books/1316637798m...
# 4  https://images.gr-assets.com/books/1328768789m...
#
#                                           mod_title
# 0    the unschooled wizard sun wolf and starhawk 12
# 1                              best friends forever
# 2                     the aeneid for boys and girls
# 3  alls fairy in love and war avalon web of magic 8
# 4                               the devils notebook

# %% [markdown]
# Creating Initial Book recommendations

# %%
books_titles[books_titles["book_id"].isin(top_recs)] #find all the book titles where the book_id is in the top 10 recommendations
# Out:
#           book_id                                              title  ratings  \
# 53027       77203                                    The Kite Runner  1848782
# 284473    2767052            The Hunger Games (The Hunger Games, #1)  4899965
# 401395       5107                             The Catcher in the Rye  2086945
# 463463       4671                                   The Great Gatsby  2758812
# 615314       5470                                               1984  2023937
# 757376      38447                                The Handmaid's Tale   648783
# 790927       2657                              To Kill a Mockingbird  3255518
# 878151   18143977                        All the Light We Cannot See   498685
# 878545          3  Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 1062354  29983711                                           Pachinko     8161
#
#                                                        url  \
# 53027    https://www.goodreads.com/book/show/77203.The_...
# 284473   https://www.goodreads.com/book/show/2767052-th...
# 401395   https://www.goodreads.com/book/show/5107.The_C...
# 463463   https://www.goodreads.com/book/show/4671.The_G...
# 615314       https://www.goodreads.com/book/show/5470.1984
# 757376   https://www.goodreads.com/book/show/38447.The_...
# 790927   https://www.goodreads.com/book/show/2657.To_Ki...
# 878151   https://www.goodreads.com/book/show/18143977-a...
# 878545   https://www.goodreads.com/book/show/3.Harry_Po...
# 1062354  https://www.goodreads.com/book/show/29983711-p...
#
#                                                cover_image  \
# 53027    https://images.gr-assets.com/books/1484565687m...
# 284473   https://images.gr-assets.com/books/1447303603m...
# 401395   https://images.gr-assets.com/books/1398034300m...
# 463463   https://images.gr-assets.com/books/1490528560m...
# 615314   https://images.gr-assets.com/books/1348990566m...
# 757376   https://images.gr-assets.com/books/1498057733m...
# 790927   https://images.gr-assets.com/books/1361975680m...
# 878151   https://images.gr-assets.com/books/1451445646m...
# 878545   https://images.gr-assets.com/books/1474154022m...
# 1062354  https://images.gr-assets.com/books/1462393298m...
#
#                                                  mod_title
# 53027                                      the kite runner
# 284473                 the hunger games the hunger games 1
# 401395                              the catcher in the rye
# 463463                                    the great gatsby
# 615314                                                1984
# 757376                                  the handmaids tale
# 790927                               to kill a mockingbird
# 878151                         all the light we cannot see
# 878545   harry potter and the sorcerers stone harry pot...
# 1062354                                           pachinko

# %% [markdown]
# # **Improving** **the** **book** **recommendations**:
#
# The books shown above seems to be the most popular books and it is not likely to be a book that we are interested in.Let's find a way to have books based on our preference not a generic preferences.

# %%
all_recs = recs ["book_id"].value_counts() # dataframe of how many times each books appears in the set

# %%
all_recs
# Out:
# 2767052     1092
# 29983711    1089
# 2657        1074
# 3           1048
# 4671        1028
#             ...
# 21843400       1
# 18595019       1
# 22514204       1
# 22733082       1
# 18781576       1
# Name: book_id, Length: 364169, dtype: int64

# %%
all_recs = all_recs.to_frame().reset_index() # convert the series into a data frame, make the index the columns which is the book id that we are interested in

# %%
all_recs
# Out:
#            index  book_id
# 0        2767052     1092
# 1       29983711     1089
# 2           2657     1074
# 3              3     1048
# 4           4671     1028
# ...          ...      ...
# 364164  21843400        1
# 364165  18595019        1
# 364166  22514204        1
# 364167  22733082        1
# 364168  18781576        1
#
# [364169 rows x 2 columns]

# %% [markdown]
# looking at all_recs ouput , book_id is named incorrectly , it is suppose to be how many times each book appears and index is the actual book_id. To fix it we'll rename the columns

# %%
all_recs.columns = ["book_id", "book_count"]

# %%
all_recs
# Out:
#          book_id  book_count
# 0        2767052        1092
# 1       29983711        1089
# 2           2657        1074
# 3              3        1048
# 4           4671        1028
# ...          ...         ...
# 364164  21843400           1
# 364165  18595019           1
# 364166  22514204           1
# 364167  22733082           1
# 364168  18781576           1
#
# [364169 rows x 2 columns]

# %%
all_recs = all_recs.merge(books_titles, how= "inner", on="book_id") # merge the above set into a book tittles, inner merge (if the data doesn't exist in both then it will remove it. )

# %%
all_recs
# Out:
#          book_id  book_count  \
# 0        2767052        1092
# 1       29983711        1089
# 2           2657        1074
# 3              3        1048
# 4           4671        1028
# ...          ...         ...
# 328338  22707746           1
# 328339  21843400           1
# 328340  18595019           1
# 328341  22514204           1
# 328342  18781576           1
#
#                                                     title  ratings  \
# 0                 The Hunger Games (The Hunger Games, #1)  4899965
# 1                                                Pachinko     8161
# 2                                   To Kill a Mockingbird  3255518
# 3       Harry Potter and the Sorcerer's Stone (Harry P...  4765497
# 4                                        The Great Gatsby  2758812
# ...                                                   ...      ...
# 328338                            Names Can Never Hurt Me      297
# 328339  Blackbird Knitting in a Bunny's Lair (Granby K...      604
# 328340                                           Bar None       25
# 328341                   Unexpected Trust (Unexpected #2)      121
# 328342                           Wolverine: Old Man Logan      891
#
#                                                       url  \
# 0       https://www.goodreads.com/book/show/2767052-th...
# 1       https://www.goodreads.com/book/show/29983711-p...
# 2       https://www.goodreads.com/book/show/2657.To_Ki...
# 3       https://www.goodreads.com/book/show/3.Harry_Po...
# 4       https://www.goodreads.com/book/show/4671.The_G...
# ...                                                   ...
# 328338  https://www.goodreads.com/book/show/22707746-n...
# 328339  https://www.goodreads.com/book/show/21843400-b...
# 328340  https://www.goodreads.com/book/show/18595019-b...
# 328341  https://www.goodreads.com/book/show/22514204-u...
# 328342  https://www.goodreads.com/book/show/18781576-w...
#
#                                               cover_image  \
# 0       https://images.gr-assets.com/books/1447303603m...
# 1       https://images.gr-assets.com/books/1462393298m...
# 2       https://images.gr-assets.com/books/1361975680m...
# 3       https://images.gr-assets.com/books/1474154022m...
# 4       https://images.gr-assets.com/books/1490528560m...
# ...                                                   ...
# 328338  https://images.gr-assets.com/books/1405051347m...
# 328339  https://images.gr-assets.com/books/1396575651m...
# 328340  https://images.gr-assets.com/books/1380480671m...
# 328341  https://images.gr-assets.com/books/1403721300m...
# 328342  https://s.gr-assets.com/assets/nophoto/book/11...
#
#                                                 mod_title
# 0                     the hunger games the hunger games 1
# 1                                                pachinko
# 2                                   to kill a mockingbird
# 3       harry potter and the sorcerers stone harry pot...
# 4                                        the great gatsby
# ...                                                   ...
# 328338                            names can never hurt me
# 328339  blackbird knitting in a bunnys lair granby kni...
# 328340                                           bar none
# 328341                      unexpected trust unexpected 2
# 328342                            wolverine old man logan
#
# [328343 rows x 7 columns]

# %%
all_recs["score"] = all_recs ["book_count"] * (all_recs["book_count"]/ all_recs["ratings"]) # the book_count of all the users with similar interest in our book, how many are there. And exclude the popularity of the book and focus on our similar book interest

# %% [markdown]
# # **Top** **10** **Books** **Recommended** **To** **Us**

# %%
all_recs.sort_values("score",ascending=False).head(10) # show the top 10 recommendations based on the new score
# Out:
#        book_id  book_count                                              title  \
# 1     29983711        1089                                           Pachinko
# 238       4408         327                                       East of Eden
# 724    9317691         175  The Name of the Wind (The Kingkiller Chronicle...
# 236   32920226         328                               Sing, Unburied, Sing
# 216   30753987         342                                        The Leavers
# 7617  26856502          27                            Vengeful (Villains, #2)
# 1287  31147619         118                                          Homegoing
# 5517  34927828          37                                    The Great Alone
# 249    8153988         322           The Eye of the World (Wheel of Time, #1)
# 6011  35099035          34                                         Red Clocks
#
#       ratings                                                url  \
# 1        8161  https://www.goodreads.com/book/show/29983711-p...
# 238      3447  https://www.goodreads.com/book/show/4408.East_...
# 724      1043  https://www.goodreads.com/book/show/9317691-th...
# 236      4592  https://www.goodreads.com/book/show/32920226-s...
# 216      5602  https://www.goodreads.com/book/show/30753987-t...
# 7617       35  https://www.goodreads.com/book/show/26856502-v...
# 1287      697  https://www.goodreads.com/book/show/31147619-h...
# 5517       70  https://www.goodreads.com/book/show/34927828-t...
# 249      5740  https://www.goodreads.com/book/show/8153988-th...
# 6011       67  https://www.goodreads.com/book/show/35099035-r...
#
#                                             cover_image  \
# 1     https://images.gr-assets.com/books/1462393298m...
# 238   https://images.gr-assets.com/books/1323882457m...
# 724   https://images.gr-assets.com/books/1360558233m...
# 236   https://images.gr-assets.com/books/1499340866m...
# 216   https://images.gr-assets.com/books/1489158974m...
# 7617  https://s.gr-assets.com/assets/nophoto/book/11...
# 1287  https://images.gr-assets.com/books/1491119004m...
# 5517  https://images.gr-assets.com/books/1501852384m...
# 249   https://images.gr-assets.com/books/1465920672m...
# 6011  https://images.gr-assets.com/books/1494345016m...
#
#                                             mod_title       score
# 1                                            pachinko  145.315648
# 238                                      east of eden   31.020888
# 724   the name of the wind the kingkiller chronicle 1   29.362416
# 236                                sing unburied sing   23.428571
# 216                                       the leavers   20.878972
# 7617                              vengeful villains 2   20.828571
# 1287                                        homegoing   19.977044
# 5517                                  the great alone   19.557143
# 249              the eye of the world wheel of time 1   18.063415
# 6011                                       red clocks   17.253731

# %% [markdown]
# looking at the table above we can see that the first 3 books we picked are mentioned and they are others books that as fewer ratings and they are popular but they are not based on the majority of likes, they are based on our interests.

# %%
popular_recs = all_recs[all_recs["book_count"] >75].sort_values("score",ascending=False) # only take recommendation where book_count =75

# %%
def make_clickable(val):
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)


popular_recs[~popular_recs["book_id"].isin(liked_books)].head(10).style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_a18e2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a18e2_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_a18e2_level0_col1" class="col_heading level0 col1" >book_count</th>
#       <th id="T_a18e2_level0_col2" class="col_heading level0 col2" >title</th>
#       <th id="T_a18e2_level0_col3" class="col_heading level0 col3" >ratings</th>
#       <th id="T_a18e2_level0_col4" class="col_heading level0 col4" >url</th>
#       <th id="T_a18e2_level0_col5" class="col_heading level0 col5" >cover_image</th>
#       <th id="T_a18e2_level0_col6" class="col_heading level0 col6" >mod_title</th>
#       <th id="T_a18e2_level0_col7" class="col_heading level0 col7" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a18e2_level0_row0" class="row_heading level0 row0" >236</th>
#       <td id="T_a18e2_row0_col0" class="data row0 col0" >32920226</td>
#       <td id="T_a18e2_row0_col1" class="data row0 col1" >328</td>
#       <td id="T_a18e2_row0_col2" class="data row0 col2" >Sing, Unburied, Sing</td>
#       <td id="T_a18e2_row0_col3" class="data row0 col3" >4592</td>
#       <td id="T_a18e2_row0_col4" class="data row0 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/32920226-sing-unburied-sing">Goodreads</a></td>
#       <td id="T_a18e2_row0_col5" class="data row0 col5" ><a href="https://images.gr-assets.com/books/1499340866m/32920226.jpg"><img src="https://images.gr-assets.com/books/1499340866m/32920226.jpg" width=50></img></a></td>
#       <td id="T_a18e2_row0_col6" class="data row0 col6" >sing unburied sing</td>
#       <td id="T_a18e2_row0_col7" class="data row0 col7" >23.428571</td>
#     </tr>
#     <tr>
#       <th id="T_a18e2_level0_row1" class="row_heading level0 row1" >216</th>
#       <td id="T_a18e2_row1_col0" class="data row1 col0" >30753987</td>
#       <td id="T_a18e2_row1_col1" class="data row1 col1" >342</td>
#       <td id="T_a18e2_row1_col2" class="data row1 col2" >The Leavers</td>
#       <td id="T_a18e2_row1_col3" class="data row1 col3" >5602</td>
#       <td id="T_a18e2_row1_col4" class="data row1 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/30753987-the-leavers">Goodreads</a></td>
#       <td id="T_a18e2_row1_col5" class="data row1 col5" ><a href="https://images.gr-assets.com/books/1489158974m/30753987.jpg"><img src="https://images.gr-assets.com/books/1489158974m/30753987.jpg" width=50></img></a></td>
#       <td id="T_a18e2_row1_col6" class="data row1 col6" >the leavers</td>
#       <td id="T_a18e2_row1_col7" class="data row1 col7" >20.878972</td>
#     </tr>
#     <tr>
#       <th id="T_a18e2_level0_row2" class="row_heading level0 row2" >441</th>
#       <td id="T_a18e2_row2_col0" class="data row2 col0" >33253215</td>
#       <td id="T_a18e2_row2_col1" class="data row2 col1" >236</td>
#       <td id="T_a18e2_row2_col2" class="data row2 col2" >The Heart's Invisible Furies</td>
#       <td id="T_a18e2_row2_col3" class="data row2 col3" >3629</td>
#       <td id="T_a18e2_row2_col4" class="data row2 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/33253215-the-heart-s-invisible-furies">Goodreads</a></td>
#       <td id="T_a18e2_row2_col5" class="data row2 col5" ><a href="https://images.gr-assets.com/books/1490803456m/33253215.jpg"><img src="https://images.gr-assets.com/books/1490803456m/33253215.jpg" width=50></img></a></td>
#       <td id="T_a18e2_row2_col6" class="data row2 col6" >the hearts invisible furies</td>
#       <td id="T_a18e2_row2_col7" class="data row2 col7" >15.347479</td>
#     </tr>
#     <tr>
#       <th id="T_a18e2_level0_row3" class="row_heading level0 row3" >692</th>
#       <td id="T_a18e2_row3_col0" class="data row3 col0" >33280160</td>
#       <td id="T_a18e2_row3_col1" class="data row3 col1" >181</td>
#       <td id="T_a18e2_row3_col2" class="data row3 col2" >What We Lose</td>
#       <td id="T_a18e2_row3_col3" class="data row3 col3" >2250</td>
#       <td id="T_a18e2_row3_col4" class="data row3 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/33280160-what-we-lose">Goodreads</a></td>
#       <td id="T_a18e2_row3_col5" class="data row3 col5" ><a href="https://images.gr-assets.com/books/1492235781m/33280160.jpg"><img src="https://images.gr-assets.com/books/1492235781m/33280160.jpg" width=50></img></a></td>
#       <td id="T_a18e2_row3_col6" class="data row3 col6" >what we lose</td>
#       <td id="T_a18e2_row3_col7" class="data row3 col7" >14.560444</td>
#     </tr>
#     <tr>
#       <th id="T_a18e2_level0_row4" class="row_heading level0 row4" >671</th>
#       <td id="T_a18e2_row4_col0" class="data row4 col0" >33621427</td>
#       <td id="T_a18e2_row4_col1" class="data row4 col1" >184</td>
#       <td id="T_a18e2_row4_col2" class="data row4 col2" >Home Fire</td>
#       <td id="T_a18e2_row4_col3" class="data row4 col3" >2390</td>
#       <td id="T_a18e2_row4_col4" class="data row4 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/33621427-home-fire">Goodreads</a></td>
#       <td id="T_a18e2_row4_col5" class="data row4 col5" ><a href="https://images.gr-assets.com/books/1500032043m/33621427.jpg"><img src="https://images.gr-assets.com/books/1500032043m/33621427.jpg" width=50></img></a></td>
#       <td id="T_a18e2_row4_col6" class="data row4 col6" >home fire</td>
#       <td id="T_a18e2_row4_col7" class="data row4 col7" >14.165690</td>
#     </tr>
#     <tr>
#       <th id="T_a18e2_level0_row5" class="row_heading level0 row5" >763</th>
#       <td id="T_a18e2_row5_col0" class="data row5 col0" >21032488</td>
#       <td id="T_a18e2_row5_col1" class="data row5 col1" >169</td>
#       <td id="T_a18e2_row5_col2" class="data row5 col2" >Doors of Stone (The Kingkiller Chronicle, #3)</td>
#       <td id="T_a18e2_row5_col3" class="data row5 col3" >2059</td>
#       <td id="T_a18e2_row5_col4" class="data row5 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/21032488-doors-of-stone">Goodreads</a></td>
#       <td id="T_a18e2_row5_col5" class="data row5 col5" ><a href="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png"><img src="https://s.gr-assets.com/assets/nophoto/book/111x148-bcc042a9c91a29c1d680899eff700a03.png" width=50></img></a></td>
#       <td id="T_a18e2_row5_col6" class="data row5 col6" >doors of stone the kingkiller chronicle 3</td>
#       <td id="T_a18e2_row5_col7" class="data row5 col7" >13.871297</td>
#     </tr>
#     <tr>
#       <th id="T_a18e2_level0_row6" class="row_heading level0 row6" >990</th>
#       <td id="T_a18e2_row6_col0" class="data row6 col0" >30971664</td>
#       <td id="T_a18e2_row6_col1" class="data row6 col1" >142</td>
#       <td id="T_a18e2_row6_col2" class="data row6 col2" >Salt Houses</td>
#       <td id="T_a18e2_row6_col3" class="data row6 col3" >1474</td>
#       <td id="T_a18e2_row6_col4" class="data row6 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/30971664-salt-houses">Goodreads</a></td>
#       <td id="T_a18e2_row6_col5" class="data row6 col5" ><a href="https://images.gr-assets.com/books/1474820735m/30971664.jpg"><img src="https://images.gr-assets.com/books/1474820735m/30971664.jpg" width=50></img></a></td>
#       <td id="T_a18e2_row6_col6" class="data row6 col6" >salt houses</td>
#       <td id="T_a18e2_row6_col7" class="data row6 col7" >13.679783</td>
#     </tr>
#     <tr>
#       <th id="T_a18e2_level0_row7" class="row_heading level0 row7" >71</th>
#       <td id="T_a18e2_row7_col0" class="data row7 col0" >30688435</td>
#       <td id="T_a18e2_row7_col1" class="data row7 col1" >533</td>
#       <td id="T_a18e2_row7_col2" class="data row7 col2" >Exit West</td>
#       <td id="T_a18e2_row7_col3" class="data row7 col3" >21378</td>
#       <td id="T_a18e2_row7_col4" class="data row7 col4" ><a target="_blank" href="https://www.goodreads.com/book/show/30688435-exit-west">Goodreads</a></td>
#       <td id="T_a18e2_row7_col5" class="data row7 col5" ><a href="https://images.gr-assets.com/books/1477324680m/30688435.jpg"><img src="https://images.gr-as

# %% [markdown]
# # **Collaborative** **Filtering**
#
# This method is another method of analysis for the book recommendations. It will an extension of the previous analysis.

# %% [markdown]
# Use Goodreads interactions Book tittle.json :
#
# book_id
# title
# ratings
# url
# Cover Image Use book_id map

# %%
import pandas as pd

my_books = pd.read_csv("/content/drive/MyDrive/Data Magic Uploads/Data/liked_books.csv", index_col=0) #read the liked book file created based on the interest

# %%
my_books
# Out:
#      user_id   book_id  rating  \
# 0         -1   2517439       5
# 1         -1    113576       5
# 2         -1     35100       5
# 3         -1    228221       5
# 5         -1  17662739       5
# 6         -1    356824       5
# 7         -1  12125412       5
# 8         -1    139069       5
# 10        -1     76680       5
# 11        -1      1898       5
# 12        -1   5096865       5
# 13        -1    228665       5
# 17        -1    437143       5
# 18        -1  18949861       5
# 19        -1   2913377       5
# 20        -1   1215032       5
# 21        -1    883438       5
# 22        -1   5578108       5
# 23        -1    128029       5
# 24        -1     77203       5
# 25        -1      5439       5
# 26        -1   1685995       5
# 27        -1   6448772       5
# 527       -1   8161140       1
# 528       -1     28187       1
# 531       -1  25659450       1
# 532       -1     82599       1
#
#                                                  title
# 0               The Forever War  (The Forever War, #1)
# 1    The Smartest Guys in the Room: The Amazing Ris...
# 2                                Battle Cry of Freedom
# 3                                  The Mask of Command
# 5           2001: A Space Odyssey  (Space Odyssey, #1)
# 6    India After Gandhi: The History of the World's...
# 7      The Lady or the Tiger?: and Other Logic Puzzles
# 8            Endurance: Shackleton's Incredible Voyage
# 10                        Foundation  (Foundation, #1)
# 11   Into Thin Air: A Personal Account of the Mount...
# 12                                       In Cold Blood
# 13       The Eye of the World  (The Wheel of Time, #1)
# 17                A Short History of Nearly Everything
# 18                                             Contact
# 19   The Name of the Wind  (The Kingkiller Chronicl...
# 20   The Wise Man's Fear  (The Kingkiller Chronicle...
# 21                                        East of Eden
# 22   From Colony to Superpower: U.S. Foreign Relati...
# 23                            A Thousand Splendid Suns
# 24                                     The Kite Runner
# 25                             Interpreter of Maladies
# 26                                     Dune  (Dune #1)
# 27   Quantum: Einstein, Bohr, and the Great Debate ...
# 527                                       On the Beach
# 528  The Lightning Thief  (Percy Jackson and the Ol...
# 531                                          Arkwright
# 532                                   Rabbits: A Novel

# %%
my_books["book_id"] = my_books["book_id"].astype(str) # make sure book_id is a string to match it with other files

# %% [markdown]
# Finding Similar Users based on book interest

# %%
# !head "/content/drive/MyDrive/Data Magic Uploads/Data/book_id_map.csv"
# Out:
# book_id_csv,book_id
# 0,34684622
# 1,34536488
# 2,34017076
# 3,71730
# 4,30422361
# 5,33503613
# 6,33517540
# 7,34467031
# 8,6383669

# %%
csv_book_mapping = {} # Read the file line by line instead of reading the whole file because the file is huge

with open("/content/drive/MyDrive/Data Magic Uploads/Data/book_id_map.csv", "r") as f:
    while True:
        line = f.readline()
        if not line:
            break
        csv_id, book_id = line.strip().split(",")
        csv_book_mapping[csv_id] = book_id

# %%
book_set = set(my_books["book_id"]) # this set like a list in python will contain all the unique books we read

# %%
overlap_users = {} # a set python data structure where every element is unique

with open("/content/drive/MyDrive/Data Magic Uploads/Data/goodreads_interactions.csv", 'r') as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ =line.split(",")# undersore means the field is not fo interest, this will give user_id, csv_id,and rating

        book_id = csv_book_mapping.get(csv_id)# get. return none if the value is not found

        if book_id in book_set: # if it is one of the book we read then let us add that user to the ovelap user dictionary
            if user_id not in overlap_users:
                overlap_users[user_id] = 1
            else:
                overlap_users[user_id] += 1 # keeping counts of how many times a given user has book overlapping form what we are interested in

# %%
len(overlap_users)
# Out:
# 316341

# %%
filtered_overlap_users = set([k for k in overlap_users if overlap_users[k] > my_books.shape[0]/5]) # look for users who had over 100 books in common with us

# %% [markdown]
# Finding Similar User Book Ratings

# %%
interactions_list = []

with open("/content/drive/MyDrive/Data Magic Uploads/Data/goodreads_interactions.csv") as f:
    while True:
        line = f.readline()
        if not line:
            break
        user_id, csv_id, _, rating, _ = line.strip().split(",")

        if user_id in filtered_overlap_users: # if the user is someone in the list of our overlap with our reads book then add the reading history into the interations list
            book_id = csv_book_mapping[csv_id]
            interactions_list.append([user_id, book_id, rating])

# %% [markdown]
# # **Build** **A** **collaborative** **filtering** **matrix**

# %% [markdown]
# A user book Matrix, every row of the matrix will be a differn user and every column of the matrix will be a different book and the cell will contain the ratings the user gave to that book.

# %%
len(interactions_list)# how long is the interactive list
# Out:
# 5638701

# %%
interactions_list[0] # first item in the list [ user_id , bood_id , bookrating ]
# Out:
# ['282', '627206', '4']

# %%
interactions = pd.DataFrame(interactions_list, columns=["user_id", "book_id", "rating"]) # turn into a dataframe

# %%
interactions = pd.concat([my_books[["user_id", "book_id", "rating"]], interactions]) # add our own rating into everyone else ratings

# %%
interactions
# Out:
#         user_id   book_id rating
# 0            -1   2517439      5
# 1            -1    113576      5
# 2            -1     35100      5
# 3            -1    228221      5
# 5            -1  17662739      5
# ...         ...       ...    ...
# 5638696  804100    475178      0
# 5638697  804100    186074      0
# 5638698  804100    153008      0
# 5638699  804100     45107      0
# 5638700  804100   1762198      5
#
# [5638728 rows x 3 columns]

# %% [markdown]
# Looking at the table, our ratings are -1 and they are others people ratings too.

# %%
interactions["book_id"] = interactions["book_id"].astype(str) # Bood_id and user_id are string like in json file
interactions["user_id"] = interactions["user_id"].astype(str)
interactions["rating"] = pd.to_numeric(interactions["rating"]) #ratings will be numbers

# %%
interactions["user_id"].unique()
# Out:
# array(['-1', '282', '874', ..., '442043', '712588', '804100'],
#       dtype=object)

# %% [markdown]
# looking at the user_id, it is shown as long numbers , the goal is to make the user_id correspond to a single row in a matrix.

# %%
interactions["user_index"] = interactions["user_id"].astype("category").cat.codes # all same number will be convert in the same category

# %%
interactions["user_index"].unique()
# Out:
# array([   0,  555, 1216, ..., 1054, 1143, 1183], dtype=int16)

# %%
interactions["book_index"] = interactions["book_id"].astype("category").cat.codes

# %%
from scipy.sparse import coo_matrix # type of sparse matrix [array or list , row position , columns position]

ratings_mat_coo = coo_matrix((interactions["rating"], (interactions["user_index"], interactions["book_index"])))

# %%
ratings_mat_coo.shape
# Out:
# (1259, 802870)

# %%
ratings_mat = ratings_mat_coo.tocsr() # convert coo to csr format

# %% [markdown]
# Finding user Similar to us

# %%
interactions[interactions["user_id"] == "-1"] # find row for specific user
# Out:
#     user_id   book_id  rating  user_index  book_index
# 0        -1   2517439       5           0      414880
# 1        -1    113576       5           0       38971
# 2        -1     35100       5           0      575858
# 3        -1    228221       5           0      356004
# 5        -1  17662739       5           0      214285
# 6        -1    356824       5           0      581743
# 7        -1  12125412       5           0       59763
# 8        -1    139069       5           0      124430
# 10       -1     76680       5           0      722098
# 11       -1      1898       5           0      276178
# 12       -1   5096865       5           0      625929
# 13       -1    228665       5           0      357774
# 17       -1    437143       5           0      607659
# 18       -1  18949861       5           0      275433
# 19       -1   2913377       5           0      496223
# 20       -1   1215032       5           0       60398
# 21       -1    883438       5           0      767233
# 22       -1   5578108       5           0      637486
# 23       -1    128029       5           0       78172
# 24       -1     77203       5           0      724379
# 25       -1      5439       5           0      633999
# 26       -1   1685995       5           0      188133
# 27       -1   6448772       5           0      671711
# 527      -1   8161140       1           0      742532
# 528      -1     28187       1           0      480322
# 531      -1  25659450       1           0      431105
# 532      -1     82599       1           0      746448

# %%
my_index = 0 #row zero in book rating matrix

# %%
from sklearn.metrics.pairwise import cosine_similarity # cos sim will find similarity between the 2 rows in the matrix

similarity = cosine_similarity(ratings_mat[my_index,:], ratings_mat).flatten()

# %%
similarity[2] # similarity of a user to us, the lower the sim matrix the less the taste in books are
# Out:
# 0.06143442518998915

# %%
import numpy as np

indices = np.argpartition(similarity, -15)[-15:] #find indices of the users most similar to us in therm of book taste

# %%
indices
# Out:
# array([1188,  942,  218,  129,  496,  435, 1208,  795, 1213, 1210, 1143,
#         321,  294,  862,    0])

# %%
similar_users = interactions[interactions["user_index"].isin(indices)].copy() # find the user_id where the user_index is in the indices

# %%
similar_users = similar_users[similar_users["user_id"]!="-1"] # looking at similar user taking our -1 which describes us to make sure we not getting our own book recommendation

# %%
similar_users
# Out:
#         user_id   book_id  rating  user_index  book_index
# 45312      4133      5359       3         942      632143
# 45313      4133  10464963       4         942       13492
# 45314      4133      3858       3         942      593622
# 45315      4133  11827808       4         942       51904
# 45316      4133   7913305       4         942      732465
# ...         ...       ...     ...         ...         ...
# 5638521  712588  32388712       3        1143      543119
# 5638522  712588     16322       5        1143      183365
# 5638523  712588    860543       0        1143      759827
# 5638524  712588    853510       5        1143      756768
# 5638525  712588     13890       4        1143      124251
#
# [4302 rows x 5 columns]

# %% [markdown]
# Looking at the table we have 4302 rows from potential books we want to read based on the user that are most similar to us

# %% [markdown]
# Creating book recommendations

# %%
book_recs = similar_users.groupby("book_id").rating.agg(['count', 'mean']) # how many time the book appears in the recommendation and find the mean rating

# %%
book_recs
# Out:
#           count      mean
# book_id
# 1             6  3.833333
# 100322        1  0.000000
# 100365        1  0.000000
# 10046142      1  0.000000
# 1005          3  0.000000
# ...         ...       ...
# 99561         2  2.500000
# 99610         1  3.000000
# 99664         1  4.000000
# 9969571       3  2.333333
# 99944         1  0.000000
#
# [2856 rows x 2 columns]

# %% [markdown]
# Looking at the table, each row is for a book , the count is how many times the book was recommendated to us, the mean is the score on how the users rated the book.

# %%
books_titles = pd.read_json("books_titles.json") # get the book title
books_titles["book_id"] = books_titles["book_id"].astype(str) # ensure the book id is a string

# %%
book_recs = book_recs.merge(books_titles, how="inner", on="book_id")# merge the two data sets to get the book titles of the book_id

# %%
book_recs
# Out:
#        book_id  count      mean  \
# 0            1      6  3.833333
# 1       100322      1  0.000000
# 2       100365      1  0.000000
# 3     10046142      1  0.000000
# 4         1005      3  0.000000
# ...        ...    ...       ...
# 2843     99561      2  2.500000
# 2844     99610      1  3.000000
# 2845     99664      1  4.000000
# 2846   9969571      3  2.333333
# 2847     99944      1  0.000000
#
#                                                   title  ratings  \
# 0     Harry Potter and the Half-Blood Prince (Harry ...  1713866
# 1                              Assata: An Autobiography    11057
# 2                                 The Mote in God's Eye    48736
# 3     Dancing in the Glory of Monsters: The Collapse...     2391
# 4                                   Think and Grow Rich    87634
# ...                                                 ...      ...
# 2843                                 Looking for Alaska   804587
# 2844                                The Best Laid Plans    17434
# 2845                                   The Painted Veil    24606
# 2846                                   Ready Player One   376328
# 2847                                  The Bhagavad Gita    33855
#
#                                                     url  \
# 0     https://www.goodreads.com/book/show/1.Harry_Po...
# 1     https://www.goodreads.com/book/show/100322.Assata
# 2     https://www.goodreads.com/book/show/100365.The...
# 3     https://www.goodreads.com/book/show/10046142-d...
# 4     https://www.goodreads.com/book/show/1005.Think...
# ...                                                 ...
# 2843  https://www.goodreads.com/book/show/99561.Look...
# 2844  https://www.goodreads.com/book/show/99610.The_...
# 2845  https://www.goodreads.com/book/show/99664.The_...
# 2846  https://www.goodreads.com/book/show/9969571-re...
# 2847  https://www.goodreads.com/book/show/99944.The_...
#
#                                             cover_image  \
# 0     https://images.gr-assets.com/books/1361039191m...
# 1     https://images.gr-assets.com/books/1328857268m...
# 2     https://images.gr-assets.com/books/1399490037m...
# 3     https://images.gr-assets.com/books/1328757755m...
# 4     https://s.gr-assets.com/assets/nophoto/book/11...
# ...                                                 ...
# 2843  https://images.gr-assets.com/books/1394798630m...
# 2844  https://images.gr-assets.com/books/1353374848m...
# 2845  https://images.gr-assets.com/books/1320421719m...
# 2846  https://images.gr-assets.com/books/1500930947m...
# 2847  https://images.gr-assets.com/books/1383059639m...
#
#                                               mod_title
# 0     harry potter and the halfblood prince harry po...
# 1                               assata an autobiography
# 2                                  the mote in gods eye
# 3     dancing in the glory of monsters the collapse ...
# 4                                   think and grow rich
# ...                                                 ...
# 2843                                 looking for alaska
# 2844                                the best laid plans
# 2845                                   the painted veil
# 2846                                   ready player one
# 2847                                  the bhagavad gita
#
# [2848 rows x 8 columns]

# %% [markdown]
# Raking the book recommendations

# %%
book_recs["adjusted_count"] = book_recs["count"] * (book_recs["count"] / book_recs["ratings"]) #adjusted count , the count of how many the book appears for people with our interest

# %%
book_recs["score"] = book_recs["mean"] * book_recs["adjusted_count"] # how much we might each the book, average rating from user like us

# %%
book_recs = book_recs[~book_recs["book_id"].isin(my_books["book_id"])]

# %%
my_books["mod_title"] = my_books["title"].str.replace("[^a-zA-Z0-9 ]", "", regex=True).str.lower() # take the title of the book we like and replace any characters that doesn't fall in the specifi set of charaters

# %%
my_books["mod_title"] = my_books["mod_title"].str.replace("\s+", " ", regex=True) # replace mutlple place in the row into one single space

# %%
book_recs = book_recs[~book_recs["mod_title"].isin(my_books["mod_title"])] # remove the books we liked , that we read in the recommendation

# %%
book_recs = book_recs[book_recs["count"]>2] #remove anything that appears less than twice

# %%
book_recs = book_recs[book_recs["mean"] >=4] # only find books where the mean rating is grader than 4

# %%
top_recs = book_recs.sort_values("mean", ascending=False) #sort data based on the score

# %%
top_recs
# Out:
#        book_id  count      mean  \
# 2260     62291      5  4.800000
# 600     157993      3  4.333333
# 1100     22034      3  4.333333
# 1173   2318271      3  4.333333
# 1906      4381      3  4.333333
# 243     119322      4  4.250000
# 1441   2767793      4  4.250000
# 2558     78983      4  4.250000
# 244     119324      3  4.000000
# 398      13497      4  4.000000
# 437     136251      6  4.000000
# 662   16181775      3  4.000000
# 2543     78508      3  4.000000
# 2544    785454      3  4.000000
# 2726    902715      3  4.000000
# 2775    944076      3  4.000000
#
#                                                   title  ratings  \
# 2260     A Storm of Swords (A Song of Ice and Fire, #3)   477834
# 600                                   The Little Prince   763309
# 1100                                      The Godfather   259150
# 1173                                   The Last Lecture   245804
# 1906                                     Fahrenheit 451   591506
# 243         The Golden Compass (His Dark Materials, #1)   973154
# 1441                    The Hero of Ages (Mistborn, #3)   149260
# 2558                  Kane and Abel (Kane and Abel, #1)    75215
# 244           The Subtle Knife (His Dark Materials, #2)   246697
# 398      A Feast for Crows (A Song of Ice and Fire, #4)   437398
# 437   Harry Potter and the Deathly Hallows (Harry Po...  1784684
# 662                 The Rosie Project (Don Tillman, #1)   259734
# 2543  The River of Doubt: Theodore Roosevelt's Darke...    32479
# 2544                                  Train to Pakistan    12993
# 2726         Before They Are Hanged (The First Law, #2)    70642
# 2775         Last Argument of Kings (The First Law, #3)    66986
#
#                                                     url  \
# 2260  https://www.goodreads.com/book/show/62291.A_St...
# 600   https://www.goodreads.com/book/show/157993.The...
# 1100  https://www.goodreads.com/book/show/22034.The_...
# 1173  https://www.goodreads.com/book/show/2318271.Th...
# 1906  https://www.goodreads.com/book/show/4381.Fahre...
# 243   https://www.goodreads.com/book/show/119322.The...
# 1441  https://www.goodreads.com/book/show/2767793-th...
# 2558  https://www.goodreads.com/book/show/78983.Kane...
# 244   https://www.goodreads.com/book/show/119324.The...
# 398   https://www.goodreads.com/book/show/13497.A_Fe...
# 437   https://www.goodreads.com/book/show/136251.Har...
# 662   https://www.goodreads.com/book/show/16181775-t...
# 2543  https://www.goodreads.com/book/show/78508.The_...
# 2544  https://www.goodreads.com/book/show/785454.Tra...
# 2726  https://www.goodreads.com/book/show/902715.Bef...
# 2775  https://www.goodreads.com/book/show/944076.Las...
#
#                                             cover_image  \
# 2260  https://images.gr-assets.com/books/1497931121m...
# 600   https://images.gr-assets.com/books/1367545443m...
# 1100  https://images.gr-assets.com/books/1394988109m...
# 1173  https://images.gr-assets.com/books/1388075896m...
# 1906  https://images.gr-assets.com/books/1351643740m...
# 243   https://images.gr-assets.com/books/1505766203m...
# 1441  https://images.gr-assets.com/books/1480717763m...
# 2558  https://s.gr-assets.com/assets/nophoto/book/11...
# 244   https://images.gr-assets.com/books/1505766360m...
# 398   https://images.gr-assets.com/books/1429538615m...
# 437   https://images.gr-assets.com/books/1474171184m...
# 662   https://images.gr-assets.com/books/1371651741m...
# 2543  https://images.gr-assets.com/books/1430014768m...
# 2544  https://images.gr-assets.com/books/1342220976m...
# 2726  https://s.gr-assets.com/assets/nophoto/book/11...
# 2775  https://images.gr-assets.com/books/1302062699m...
#
#                                               mod_title  adjusted_count  \
# 2260         a storm of swords a song of ice and fire 3        0.000052
# 600                                   the little prince        0.000012
# 1100                                      the godfather        0.000035
# 1173                                   the last lecture        0.000037
# 1906                                     fahrenheit 451        0.000015
# 243             the golden compass his dark materials 1        0.000016
# 1441                        the hero of ages mistborn 3        0.000107
# 2558                      kane and abel kane and abel 1        0.000213
# 244               the subtle knife his dark materials 2        0.000036
# 398          a feast for crows a song of ice and fire 4        0.000037
# 437   harry potter and the deathly hallows harry pot...        0.000020
# 662                     the rosie project don tillman 1        0.000035
# 2543  the river of doubt theodore roosevelts darkest...        0.000277
# 2544                                  train to pakistan        0.000693
# 2726             before they are hanged the first law 2        0.000127
# 2775             last argument of kings the first law 3        0.000134
#
#          score
# 2260  0.000251
# 600   0.000051
# 1100  0.000150
# 1173  0.000159
# 1906  0.000066
# 243   0.000070
# 1441  0.000456
# 2558  0.000904
# 244   0.000146
# 398   0.000146
# 437   0.000081
# 662   0.000139
# 2543  0.001108
# 2544  0.002771
# 2726  0.000510
# 2775  0.000537

# %%
def make_clickable(val): # style the data frame where we can click on the link and see the image
    return '<a target="_blank" href="{}">Goodreads</a>'.format(val, val)

def show_image(val):
    return '<a href="{}"><img src="{}" width=50></img></a>'.format(val, val)

top_recs.style.format({'url': make_clickable, 'cover_image': show_image})
# Out:
# <style type="text/css">
# </style>
# <table id="T_e7fda" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7fda_level0_col0" class="col_heading level0 col0" >book_id</th>
#       <th id="T_e7fda_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_e7fda_level0_col2" class="col_heading level0 col2" >mean</th>
#       <th id="T_e7fda_level0_col3" class="col_heading level0 col3" >title</th>
#       <th id="T_e7fda_level0_col4" class="col_heading level0 col4" >ratings</th>
#       <th id="T_e7fda_level0_col5" class="col_heading level0 col5" >url</th>
#       <th id="T_e7fda_level0_col6" class="col_heading level0 col6" >cover_image</th>
#       <th id="T_e7fda_level0_col7" class="col_heading level0 col7" >mod_title</th>
#       <th id="T_e7fda_level0_col8" class="col_heading level0 col8" >adjusted_count</th>
#       <th id="T_e7fda_level0_col9" class="col_heading level0 col9" >score</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7fda_level0_row0" class="row_heading level0 row0" >2260</th>
#       <td id="T_e7fda_row0_col0" class="data row0 col0" >62291</td>
#       <td id="T_e7fda_row0_col1" class="data row0 col1" >5</td>
#       <td id="T_e7fda_row0_col2" class="data row0 col2" >4.800000</td>
#       <td id="T_e7fda_row0_col3" class="data row0 col3" >A Storm of Swords (A Song of Ice and Fire, #3)</td>
#       <td id="T_e7fda_row0_col4" class="data row0 col4" >477834</td>
#       <td id="T_e7fda_row0_col5" class="data row0 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/62291.A_Storm_of_Swords">Goodreads</a></td>
#       <td id="T_e7fda_row0_col6" class="data row0 col6" ><a href="https://images.gr-assets.com/books/1497931121m/62291.jpg"><img src="https://images.gr-assets.com/books/1497931121m/62291.jpg" width=50></img></a></td>
#       <td id="T_e7fda_row0_col7" class="data row0 col7" >a storm of swords a song of ice and fire 3</td>
#       <td id="T_e7fda_row0_col8" class="data row0 col8" >0.000052</td>
#       <td id="T_e7fda_row0_col9" class="data row0 col9" >0.000251</td>
#     </tr>
#     <tr>
#       <th id="T_e7fda_level0_row1" class="row_heading level0 row1" >600</th>
#       <td id="T_e7fda_row1_col0" class="data row1 col0" >157993</td>
#       <td id="T_e7fda_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_e7fda_row1_col2" class="data row1 col2" >4.333333</td>
#       <td id="T_e7fda_row1_col3" class="data row1 col3" >The Little Prince</td>
#       <td id="T_e7fda_row1_col4" class="data row1 col4" >763309</td>
#       <td id="T_e7fda_row1_col5" class="data row1 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/157993.The_Little_Prince">Goodreads</a></td>
#       <td id="T_e7fda_row1_col6" class="data row1 col6" ><a href="https://images.gr-assets.com/books/1367545443m/157993.jpg"><img src="https://images.gr-assets.com/books/1367545443m/157993.jpg" width=50></img></a></td>
#       <td id="T_e7fda_row1_col7" class="data row1 col7" >the little prince</td>
#       <td id="T_e7fda_row1_col8" class="data row1 col8" >0.000012</td>
#       <td id="T_e7fda_row1_col9" class="data row1 col9" >0.000051</td>
#     </tr>
#     <tr>
#       <th id="T_e7fda_level0_row2" class="row_heading level0 row2" >1100</th>
#       <td id="T_e7fda_row2_col0" class="data row2 col0" >22034</td>
#       <td id="T_e7fda_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_e7fda_row2_col2" class="data row2 col2" >4.333333</td>
#       <td id="T_e7fda_row2_col3" class="data row2 col3" >The Godfather</td>
#       <td id="T_e7fda_row2_col4" class="data row2 col4" >259150</td>
#       <td id="T_e7fda_row2_col5" class="data row2 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/22034.The_Godfather">Goodreads</a></td>
#       <td id="T_e7fda_row2_col6" class="data row2 col6" ><a href="https://images.gr-assets.com/books/1394988109m/22034.jpg"><img src="https://images.gr-assets.com/books/1394988109m/22034.jpg" width=50></img></a></td>
#       <td id="T_e7fda_row2_col7" class="data row2 col7" >the godfather</td>
#       <td id="T_e7fda_row2_col8" class="data row2 col8" >0.000035</td>
#       <td id="T_e7fda_row2_col9" class="data row2 col9" >0.000150</td>
#     </tr>
#     <tr>
#       <th id="T_e7fda_level0_row3" class="row_heading level0 row3" >1173</th>
#       <td id="T_e7fda_row3_col0" class="data row3 col0" >2318271</td>
#       <td id="T_e7fda_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_e7fda_row3_col2" class="data row3 col2" >4.333333</td>
#       <td id="T_e7fda_row3_col3" class="data row3 col3" >The Last Lecture</td>
#       <td id="T_e7fda_row3_col4" class="data row3 col4" >245804</td>
#       <td id="T_e7fda_row3_col5" class="data row3 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2318271.The_Last_Lecture">Goodreads</a></td>
#       <td id="T_e7fda_row3_col6" class="data row3 col6" ><a href="https://images.gr-assets.com/books/1388075896m/2318271.jpg"><img src="https://images.gr-assets.com/books/1388075896m/2318271.jpg" width=50></img></a></td>
#       <td id="T_e7fda_row3_col7" class="data row3 col7" >the last lecture</td>
#       <td id="T_e7fda_row3_col8" class="data row3 col8" >0.000037</td>
#       <td id="T_e7fda_row3_col9" class="data row3 col9" >0.000159</td>
#     </tr>
#     <tr>
#       <th id="T_e7fda_level0_row4" class="row_heading level0 row4" >1906</th>
#       <td id="T_e7fda_row4_col0" class="data row4 col0" >4381</td>
#       <td id="T_e7fda_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_e7fda_row4_col2" class="data row4 col2" >4.333333</td>
#       <td id="T_e7fda_row4_col3" class="data row4 col3" >Fahrenheit 451</td>
#       <td id="T_e7fda_row4_col4" class="data row4 col4" >591506</td>
#       <td id="T_e7fda_row4_col5" class="data row4 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/4381.Fahrenheit_451">Goodreads</a></td>
#       <td id="T_e7fda_row4_col6" class="data row4 col6" ><a href="https://images.gr-assets.com/books/1351643740m/4381.jpg"><img src="https://images.gr-assets.com/books/1351643740m/4381.jpg" width=50></img></a></td>
#       <td id="T_e7fda_row4_col7" class="data row4 col7" >fahrenheit 451</td>
#       <td id="T_e7fda_row4_col8" class="data row4 col8" >0.000015</td>
#       <td id="T_e7fda_row4_col9" class="data row4 col9" >0.000066</td>
#     </tr>
#     <tr>
#       <th id="T_e7fda_level0_row5" class="row_heading level0 row5" >243</th>
#       <td id="T_e7fda_row5_col0" class="data row5 col0" >119322</td>
#       <td id="T_e7fda_row5_col1" class="data row5 col1" >4</td>
#       <td id="T_e7fda_row5_col2" class="data row5 col2" >4.250000</td>
#       <td id="T_e7fda_row5_col3" class="data row5 col3" >The Golden Compass (His Dark Materials, #1)</td>
#       <td id="T_e7fda_row5_col4" class="data row5 col4" >973154</td>
#       <td id="T_e7fda_row5_col5" class="data row5 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/119322.The_Golden_Compass">Goodreads</a></td>
#       <td id="T_e7fda_row5_col6" class="data row5 col6" ><a href="https://images.gr-assets.com/books/1505766203m/119322.jpg"><img src="https://images.gr-assets.com/books/1505766203m/119322.jpg" width=50></img></a></td>
#       <td id="T_e7fda_row5_col7" class="data row5 col7" >the golden compass his dark materials 1</td>
#       <td id="T_e7fda_row5_col8" class="data row5 col8" >0.000016</td>
#       <td id="T_e7fda_row5_col9" class="data row5 col9" >0.000070</td>
#     </tr>
#     <tr>
#       <th id="T_e7fda_level0_row6" class="row_heading level0 row6" >1441</th>
#       <td id="T_e7fda_row6_col0" class="data row6 col0" >2767793</td>
#       <td id="T_e7fda_row6_col1" class="data row6 col1" >4</td>
#       <td id="T_e7fda_row6_col2" class="data row6 col2" >4.250000</td>
#       <td id="T_e7fda_row6_col3" class="data row6 col3" >The Hero of Ages (Mistborn, #3)</td>
#       <td id="T_e7fda_row6_col4" class="data row6 col4" >149260</td>
#       <td id="T_e7fda_row6_col5" class="data row6 col5" ><a target="_blank" href="https://www.goodreads.com/book/show/2767793-the-hero-of-ages">Goodreads</a></td>
#       <td id="T_e

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# Building a book recommendation tool for beginner adult readers is a valuable solution to help them discover books they will enjoy and increase their motivation to read. The tool utilizes machine learning techniques and publicly available data to generate personalized recommendations based on users' interests, preferences, and reading levels.
# Goodreads API, which provides access to book information, user ratings, and reviews. Collaborative filtering as used to analyze the similarity between users and recommend books that are popular among similar users.The tool was build to recommend the type of the books we liked base on other users interest that are similar to our taste.The search engine can be updated to find a different genre of books after we are done reading the other books from the top 10 recommendations
